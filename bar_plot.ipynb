# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
tips=sns.load_dataset('tips')

# %%
sns.barplot(x='day',y='tip',data=tips)

# %%
sns.barplot(x='day',y='tip',hue='sex',data=tips)

# %%
sns.barplot(x='day',y='tip',hue='sex',data=tips,palette='winter_r')

# %%
sns.barplot(x='day',y='total_bill',hue='smoker',data=tips,palette='winter_r')

# %%
sns.barplot(x='total_bill',y='day',data=tips,palette='spring',order=['Sat','Fri','Thurs','Sun'])

# %%
sns.barplot(x='day',y='total_bill',data=tips,estimator=median)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-76fad1e39afe> in <module>
# ----> 1 sns.barplot(x='day',y='total_bill',data=tips,estimator=median)
#
# NameError: name 'median' is not defined

# %%
from numpy import median

# %%
sns.barplot(x='day',y='total_bill',data=tips,estimator=median)
