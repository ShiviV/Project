# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
sns.barplot(x='smoker',y='tip',data=tips,ci=99,capsize=0.3)

# %%
tips=sns.load_dataset('tips')

# %%
sns.barplot(x='smoker',y='tip',data=tips,ci=99,capsize=0.9)

# %%
sns.barplot(x='smoker',y='tip',data=tips,ci=99,capsize=0.1,palette='husl',hue='sex')

# %%
sns.barplot(x='smoker',y='tip',data=tips,ci=99,capsize=0.1,palette='autumn',hue='sex')

# %%
sns.barplot(x='size',y='tip',data=tips,ci=99,capsize=0.1,color='green',saturation=0.3)
